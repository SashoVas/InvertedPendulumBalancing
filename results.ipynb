# %%
from neat.neat import NeatAgent
from neat.visualization import plot_genome,plot_training_history
import pickle
# Out:
# pygame-ce 2.5.8 (SDL 2.32.10, Python 3.14.0)

# %%
agent = NeatAgent.load_from_file("agents/best_neat_genome_double_pendulum1.pkl")
genome = agent.genome
with open("agents/neat_history_double_pendulum1.pkl", "rb") as f:
    history = pickle.load(f)

# %%
plot_genome(genome)

# %%
plot_training_history(
    history,
    title="NEAT Pendulum Training",
)
