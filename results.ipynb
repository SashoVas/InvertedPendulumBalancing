# %%
from neat.neat import NeatAgent
from neat.visualization import plot_genome,plot_training_history
import pickle

# %%
agent = NeatAgent.load_from_file("agents/best_neat_genome_double_pendulum.pkl")
genome = agent.genome
with open("agents/neat_history_double_pendulum.pkl", "rb") as f:
    history = pickle.load(f)

# %%
plot_genome(genome)

# %%
plot_training_history(
    history,
    title="NEAT Pendulum Training",
)
